# %% [markdown]
# ### 3 Different ways to build Keras models
#
# 1. ***The Sequential model*** is the most approachable API—it’s basically a Python list.
#    As such, it’s limited to simple stacks of layers.
#
# 2. ***The Functional API***, which focuses on graph-like model architectures.
#    It represents a nice mid-point between usability and flexibility, and as such, it’s the most commonly used model-building API.
#
# 3. ***Model subclassing***, a low-level option where you write everything yourself from scratch.
#    This is ideal if you want full control over every little thing. 4
#    However, you won’t get access to many built-in Keras features, and you will be more at risk of making mistakes.

# %%
import numpy as np
import keras

# %% [markdown]
# ### The Sequential Model

# %%
#The Sequential class
model1 = keras.Sequential(
    [
        keras.layers.Dense(64, activation="relu"),
        keras.layers.Dense(10, activation="softmax"),
    ]
)
model1.weights # Models that aren’t yet built have no weights
# Out:
# []

# %%
# Calling a model for the first time to build it
model1.build(input_shape=(None, 3))
model1.weights
# Out:
# [<Variable path=sequential/dense/kernel, shape=(3, 64), dtype=float32, value=[[-0.06995715  0.11604801  0.16309622 -0.25208354  0.0720883  -0.22102028
#    -0.00245607  0.10145661  0.29529387 -0.11777292  0.27396244  0.08797908
#     0.20631087 -0.22434935  0.10387388 -0.08492292  0.18262047  0.14550474
#     0.01196653  0.18371165 -0.15954134  0.05449739 -0.18622221 -0.01596934
#    -0.03111711 -0.12833719 -0.07212277 -0.10845551 -0.28584042 -0.2841621
#    -0.12342292  0.29019082 -0.17451674 -0.21577246  0.16600049  0.19138712
#     0.23420483 -0.1756053  -0.08346365  0.29185063  0.05818847 -0.01734984
#    -0.16125326  0.06255665 -0.13760778 -0.0158487   0.13363075 -0.14841492
#    -0.18339413 -0.2762158   0.25651693 -0.268606    0.19237423 -0.2122148
#     0.1055944  -0.2163055  -0.22210091 -0.2921859   0.28974092 -0.27177083
#    -0.1499827  -0.09225494  0.16109863 -0.14539064]
#   [-0.2893891   0.00399426  0.08782932  0.0234718   0.12183973 -0.1952413
# ...

# %%
# The summary method
model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 906 (3.54 KB)
#  Trainable params: 906 (3.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Incrementally building a Sequential model
model2 = keras.Sequential()
model2.add(keras.layers.Dense(64, activation="relu"))
model2.add(keras.layers.Dense(10, activation="softmax"))
model2.weights # Models that aren’t yet built have no weights
# Out:
# []

# %%
# Calling a model for the first time to build it
model2.build(input_shape=(None, 3))
model2.weights
# Out:
# [<Variable path=sequential_1/dense_2/kernel, shape=(3, 64), dtype=float32, value=[[ 0.29700178 -0.149726    0.14367509 -0.24086058 -0.08365794 -0.23464707
#    -0.16405222 -0.26472002  0.07736737  0.07083309  0.20491034 -0.25222236
#     0.08652404  0.21616381  0.08950779 -0.00592297  0.12254041  0.238778
#    -0.17212418 -0.07078528 -0.11348529  0.02579358  0.2524078  -0.03269517
#     0.1522803  -0.18026942  0.12653145 -0.07139787 -0.03797674 -0.22884095
#    -0.14245528  0.07035905  0.05450994 -0.05090454  0.08378464 -0.04810131
#     0.10940927  0.25033516 -0.11408597 -0.24271718  0.01250234 -0.22145528
#     0.00728101  0.11563006 -0.12768571  0.1551668  -0.12426789 -0.27226907
#     0.1212897  -0.14564814 -0.26147842 -0.12331498 -0.2872192   0.08637628
#    -0.25742987 -0.11858492  0.25167662  0.16389212  0.0807713   0.00999734
#     0.00587538  0.28300387  0.19370106 -0.06281912]
#   [-0.29015616 -0.18595067 -0.1903705  -0.07462463 -0.07055554 -0.1929375
# ...

# %%
# The summary method
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 906 (3.54 KB)
#  Trainable params: 906 (3.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Naming models and layers with the name argument
model3 = keras.Sequential(name="my_example_model")
model3.add(keras.layers.Dense(64, activation="relu", name="my_first_layer"))
model3.add(keras.layers.Dense(10, activation="softmax", name="my_last_layer"))
model3.build((None, 3))
model3.summary()
# Out:
# Model: "my_example_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ my_first_layer (Dense)          │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ my_last_layer (Dense)           │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 906 (3.54 KB)
#  Trainable params: 906 (3.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Specifying the input shape of your model in advance
model4 = keras.Sequential()
model4.add(keras.Input(shape=(3,)))
model4.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model4.add(keras.layers.Dense(64, activation="relu"))
model4.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │           256 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 256 (1.00 KB)
#  Trainable params: 256 (1.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model4.add(keras.layers.Dense(64, activation="relu"))
model4.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         4,160 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,416 (17.25 KB)
#  Trainable params: 4,416 (17.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model4.add(keras.layers.Dense(10, activation="softmax"))
model4.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,066 (19.79 KB)
#  Trainable params: 5,066 (19.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### The Functional API

# %%
# A simple Functional model with two Dense layers
inputs = keras.Input(shape=(3,), name="my_input")
features = keras.layers.Dense(64, activation="relu")(inputs)
outputs = keras.layers.Dense(10, activation="softmax")(features)
model1 = keras.Model(inputs=inputs, outputs=outputs, name="my_functional_model")
model1.summary()
# Out:
# Model: "my_functional_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ my_input (InputLayer)           │ (None, 3)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 906 (3.54 KB)
#  Trainable params: 906 (3.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
inputs.shape
# Out:
# (None, 3)

# %%
inputs.dtype
# Out:
# 'float32'

# %%
features.shape
# Out:
# (None, 64)

# %%
features.dtype
# Out:
# 'float32'

# %%
features
# Out:
# <KerasTensor shape=(None, 64), dtype=float32, sparse=False, ragged=False, name=keras_tensor_16>

# %%
# A multi-input, multi-output Functional model
vocabulary_size = 10000
num_tags = 100
num_departments = 4

title = keras.Input(shape=(vocabulary_size,), name="title")
text_body = keras.Input(shape=(vocabulary_size,), name="text_body")
tags = keras.Input(shape=(num_tags,), name="tags")

features = keras.layers.Concatenate()([title, text_body, tags])

features = keras.layers.Dense(64, activation="relu", name="dense_features")(features)
priority = keras.layers.Dense(1, activation="sigmoid", name="priority")(features)
department = keras.layers.Dense(num_departments, activation="softmax", name="department")(features)

model = keras.Model(
    inputs=[title, text_body, tags],
    outputs=[priority, department],
)
model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ title (InputLayer)  │ (None, 10000)     │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ text_body           │ (None, 10000)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tags (InputLayer)   │ (None, 100)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 20100)     │          0 │ title[0][0],      │
# │ (Concatenate)       │                   │            │ text_body[0][0],  │
# ...

# %%
# Training a above model by providing lists of input and target arrays

num_samples = 1280

title_data = np.random.randint(0, 2, size=(num_samples, vocabulary_size))
text_body_data = np.random.randint(0, 2, size=(num_samples, vocabulary_size))
tags_data = np.random.randint(0, 2, size=(num_samples, num_tags))
priority_data = np.random.random(size=(num_samples, 1))
department_data = np.random.randint(0, num_departments, size=(num_samples, 1))

model.compile(optimizer="adam", loss=["mean_squared_error", "sparse_categorical_crossentropy"],metrics=[["mean_absolute_error"], ["accuracy"]])

model.fit([title_data, text_body_data, tags_data], [priority_data, department_data], epochs=10)

model.evaluate([title_data, text_body_data, tags_data], [priority_data, department_data])
priority_preds, department_preds = model.predict([title_data, text_body_data, tags_data])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - department_accuracy: 0.2359 - department_loss: 2.9311 - loss: 3.2533 - priority_loss: 0.3222 - priority_mean_absolute_error: 0.4880
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - department_accuracy: 0.4664 - department_loss: 1.3044 - loss: 1.6321 - priority_loss: 0.3277 - priority_mean_absolute_error: 0.4937
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - department_accuracy: 0.8367 - department_loss: 0.6383 - loss: 0.8479 - priority_loss: 0.2096 - priority_mean_absolute_error: 0.3774
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - department_accuracy: 0.9906 - department_loss: 0.3632 - loss: 0.4754 - priority_loss: 0.1122 - priority_mean_absolute_error: 0.2721
# Epoch 5/10
# ...

# %%
# Training a model by providing dicts of input and target arrays
model.compile(
    optimizer="adam",
    loss={
        "priority": "mean_squared_error",
        "department": "sparse_categorical_crossentropy",
    },
    metrics={
        "priority": ["mean_absolute_error"],
        "department": ["accuracy"],
    },
)
model.fit(
    {"title": title_data, "text_body": text_body_data, "tags": tags_data},
    {"priority": priority_data, "department": department_data},
    epochs=10,
)
model.evaluate(
    {"title": title_data, "text_body": text_body_data, "tags": tags_data},
    {"priority": priority_data, "department": department_data},
)
priority_preds, department_preds = model.predict(
    {"title": title_data, "text_body": text_body_data, "tags": tags_data}
)
# Out:
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - department_accuracy: 0.0000e+00 - department_loss: 0.8455 - loss: 0.9781 - priority_loss: 0.1326 - priority_mean_absolute_error: 1.4175
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - department_accuracy: 0.0000e+00 - department_loss: 0.1853 - loss: 0.2691 - priority_loss: 0.0838 - priority_mean_absolute_error: 1.3945
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - department_accuracy: 0.0000e+00 - department_loss: 0.1396 - loss: 0.2180 - priority_loss: 0.0784 - priority_mean_absolute_error: 1.3775
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - department_accuracy: 0.0000e+00 - department_loss: 0.1083 - loss: 0.1834 - priority_loss: 0.0751 - priority_mean_absolute_error: 1.3756
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - department_accuracy: 0.0000e+00 - department_loss: 0.0853 - loss: 0.1525 - priority_loss: 0.0672 - priority_mean_absolute_error: 1.3752
# Epoch 6/10
# ...

# %%
# ! pip install pydot
# !! pip install graphviz
keras.utils.plot_model(model, "ticket_classifier.png")
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
model.layers
# Out:
# [<InputLayer name=title, built=True>,
#  <InputLayer name=text_body, built=True>,
#  <InputLayer name=tags, built=True>,
#  <Concatenate name=concatenate, built=True>,
#  <Dense name=dense_features, built=True>,
#  <Dense name=priority, built=True>,
#  <Dense name=department, built=True>]

# %%
model.input
# Out:
# [<KerasTensor shape=(None, 10000), dtype=float32, sparse=False, ragged=False, name=title>,
#  <KerasTensor shape=(None, 10000), dtype=float32, sparse=False, ragged=False, name=text_body>,
#  <KerasTensor shape=(None, 100), dtype=float32, sparse=False, ragged=False, name=tags>]

# %%
model.output
# Out:
# [<KerasTensor shape=(None, 1), dtype=float32, sparse=False, ragged=False, name=keras_tensor_20>,
#  <KerasTensor shape=(None, 4), dtype=float32, sparse=False, ragged=False, name=keras_tensor_21>]

# %%
model.layers[3]
# Out:
# <Concatenate name=concatenate, built=True>

# %%
model.layers[3].output
# Out:
# <KerasTensor shape=(None, 20100), dtype=float32, sparse=False, ragged=False, name=keras_tensor_18>

# %%
# Creating a new model by reusing intermediate layer outputs
features = model.layers[4].output
difficulty = keras.layers.Dense(3, activation="softmax", name="difficulty")(features)
new_model = keras.Model(inputs=[title, text_body, tags], outputs=[priority, department, difficulty])
new_model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ title (InputLayer)  │ (None, 10000)     │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ text_body           │ (None, 10000)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tags (InputLayer)   │ (None, 100)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 20100)     │          0 │ title[0][0],      │
# │ (Concatenate)       │                   │            │ text_body[0][0],  │
# ...

# %% [markdown]
# ### Model Subclassing

# %%
# A simple subclassed model
class CustomerTicketModel(keras.Model):
    def __init__(self, num_departments):
        super().__init__()
        self.concat_layer = keras.layers.Concatenate()
        self.mixing_layer = keras.layers.Dense(64, activation="relu")
        self.priority_scorer = keras.layers.Dense(1, activation="sigmoid")
        self.department_classifier = keras.layers.Dense(num_departments, activation="softmax")

    def call(self, inputs):
        title = inputs["title"]
        text_body = inputs["text_body"]
        tags = inputs["tags"]
        features = self.concat_layer([title, text_body, tags])
        features = self.mixing_layer(features)
        priority = self.priority_scorer(features)
        department = self.department_classifier(features)
        return priority, department

# %%
model = CustomerTicketModel(num_departments=4)
priority, department = model({"title": title_data, "text_body": text_body_data, "tags": tags_data})

# %%
model.compile(
    optimizer="adam",
    loss=["mean_squared_error", "sparse_categorical_crossentropy"],
    metrics=[["mean_absolute_error"], ["accuracy"]],
)
model.fit(
    {"title": title_data, "text_body": text_body_data, "tags": tags_data},
    [priority_data, department_data],
    epochs=10,
)
# Out:
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.2711 - loss: 1.7409 - mean_absolute_error: 0.2699 - mean_squared_error_loss: 0.1024 - sparse_categorical_crossentropy_loss: 1.6385
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2562 - loss: 1.4726 - mean_absolute_error: 0.2509 - mean_squared_error_loss: 0.0852 - sparse_categorical_crossentropy_loss: 1.3874
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2562 - loss: 1.4681 - mean_absolute_error: 0.2515 - mean_squared_error_loss: 0.0850 - sparse_categorical_crossentropy_loss: 1.3831
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2570 - loss: 1.4675 - mean_absolute_error: 0.2507 - mean_squared_error_loss: 0.0845 - sparse_categorical_crossentropy_loss: 1.3830
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2570 - loss: 1.4674 - mean_absolute_error: 0.2506 - mean_squared_error_loss: 0.0845 - sparse_categorical_crossentropy_loss: 1.3829
# ...

# %%
model.evaluate(
{"title": title_data, "text_body": text_body_data, "tags": tags_data},
[priority_data, department_data],
)
priority_preds, department_preds = model.predict(
{"title": title_data, "text_body": text_body_data, "tags": tags_data}
)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2641 - loss: 1.4670 - mean_absolute_error: 0.2505 - mean_squared_error_loss: 0.0845 - sparse_categorical_crossentropy_loss: 1.3825
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
model.summary()
# Out:
# Model: "customer_ticket_model_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ concatenate_2 (Concatenate)     │ (1280, 20100)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (1280, 64)             │     1,286,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (1280, 1)              │            65 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (1280, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,860,369 (14.73 MB)
#  Trainable params: 1,286,789 (4.91 MB)
# ...
