# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import keras_hub
import tensorflow as tf

# %% [markdown]
# ### Load test Image

# %%
img_path = keras.utils.get_file(fname="cat.jpg", origin="https://img-datasets.s3.amazonaws.com/cat.jpg")

def get_img_array(img_path, target_size):
    img = keras.utils.load_img(img_path, target_size=target_size)
    array = keras.utils.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array

img_tensor = get_img_array(img_path, target_size=(180, 180))

# %%
plt.axis("off")
plt.imshow(img_tensor[0].astype("uint8"))
plt.show()

# %% [markdown]
# ### Load Model

# %%
model = keras_hub.models.Backbone.from_preset("xception_41_imagenet")
preprocessor = keras.Sequential([
    keras.layers.Resizing(180, 180, interpolation="bilinear", crop_to_aspect_ratio=True),
    keras.layers.Rescaling(scale=1.0 / 127.5, offset=-1.0)
])
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "xception_backbone"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, None,      │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, None,      │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, None,      │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, None,      │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, None,      │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, None,      │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, None,      │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, None,      │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, None,      │          0 │ block2_sepconv1_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, None,      │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, None,      │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_residual_co… │ (None, None,      │      8,192 │ block1_conv2_act… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, None,      │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_residual_bn  │ (None, None,      │        512 │ block2_residual_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_residual_add │ (None, None,      │          0 │ block2_pool[0][0… │
# │ (Add)               │ None, 128)        │            │ block2_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, None,      │          0 │ block2_residual_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, None,      │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, None,      │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, None,      │          0 │ block3_sepconv1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, None,      │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, None,      │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_residual_co… │ (None, None,      │     32,768 │ block2_residual_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, None,      │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_residual_bn  │ (None, None,      │      1,024 │ block3_residual_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_residual_add │ (None, None,      │          0 │ block3_pool[0][0… │
# │ (Add)               │ None, 256)        │            │ block3_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, None,      │          0 │ block3_residual_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, None,      │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, None,      │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, None,      │          0 │ block4_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, None,      │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, None,      │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_residual_co… │ (None, None,      │    186,368 │ block3_residual_… │
# │ (Conv2D)            │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, None,      │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_residual_bn  │ (None, None,      │      2,912 │ block4_residual_… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_residual_add │ (None, None,      │          0 │ block4_pool[0][0… │
# │ (Add)               │ None, 728)        │            │ block4_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, None,      │          0 │ block4_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, None,      │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, None,      │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, None,      │          0 │ block5_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, None,      │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, None,      │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, None,      │          0 │ block5_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, None,      │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, None,      │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_residual_add │ (None, None,      │          0 │ block5_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block4_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, None,      │          0 │ block5_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, None,      │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, None,      │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, None,      │          0 │ block6_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, None,      │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, None,      │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, None,      │          0 │ block6_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, None,      │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, None,      │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_residual_add │ (None, None,      │          0 │ block6_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block5_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, None,      │          0 │ block6_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, None,      │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, None,      │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, None,      │          0 │ block7_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, None,      │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, None,      │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, None,      │          0 │ block7_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, None,      │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, None,      │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_residual_add │ (None, None,      │          0 │ block7_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block6_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, None,      │          0 │ block7_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, None,      │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, None,      │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, None,      │          0 │ block8_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, None,      │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, None,      │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, None,      │          0 │ block8_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, None,      │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, None,      │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_residual_add │ (None, None,      │          0 │ block8_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block7_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, None,      │          0 │ block8_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, None,      │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, None,      │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, None,      │          0 │ block9_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, None,      │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, None,      │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, None,      │          0 │ block9_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, None,      │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, None,      │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_residual_add │ (None, None,      │          0 │ block9_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block8_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, None,      │          0 │ block9_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, None,      │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, None,      │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, None,      │          0 │ block10_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, None,      │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, None,      │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, None,      │          0 │ block10_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, None,      │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, None,      │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_residual_a… │ (None, None,      │          0 │ block10_sepconv3… │
# │ (Add)               │ None, 728)        │            │ block9_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, None,      │          0 │ block10_residual… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, None,      │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, None,      │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, None,      │          0 │ block11_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, None,      │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, None,      │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, None,      │          0 │ block11_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, None,      │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, None,      │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_residual_a… │ (None, None,      │          0 │ block11_sepconv3… │
# │ (Add)               │ None, 728)        │            │ block10_residual… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, None,      │          0 │ block11_residual… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, None,      │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, None,      │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, None,      │          0 │ block12_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, None,      │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, None,      │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, None,      │          0 │ block12_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, None,      │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, None,      │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_residual_a… │ (None, None,      │          0 │ block12_sepconv3… │
# │ (Add)               │ None, 728)        │            │ block11_residual… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, None,      │          0 │ block12_residual… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, None,      │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, None,      │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, None,      │          0 │ block13_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, None,      │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, None,      │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_residual_c… │ (None, None,      │    745,472 │ block12_residual… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, None,      │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_residual_bn │ (None, None,      │      4,096 │ block13_residual… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_residual_a… │ (None, None,      │          0 │ block13_pool[0][… │
# │ (Add)               │ None, 1024)       │            │ block13_residual… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, None,      │  1,582,080 │ block13_residual… │
# │ (SeparableConv2D)   │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, None,      │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, None,      │          0 │ block14_sepconv1… │
# │ (Activation)        │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, None,      │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_bn │ (None, None,      │      8,192 │ block14_sepconv2… │
# │ (BatchNormalizatio… │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_a… │ (None, None,      │          0 │ block14_sepconv2… │
# │ (Activation)        │ None, 2048)       │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,861,480 (79.58 MB)
#  Trainable params: 20,806,952 (79.37 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
model.layers
# Out:
# [<InputLayer name=input_layer, built=True>,
#  <Conv2D name=block1_conv1, built=True>,
#  <BatchNormalization name=block1_conv1_bn, built=True>,
#  <Activation name=block1_conv1_act, built=True>,
#  <Conv2D name=block1_conv2, built=True>,
#  <BatchNormalization name=block1_conv2_bn, built=True>,
#  <Activation name=block1_conv2_act, built=True>,
#  <SeparableConv2D name=block2_sepconv1, built=True>,
#  <BatchNormalization name=block2_sepconv1_bn, built=True>,
#  <Activation name=block2_sepconv2_act, built=True>,
#  <SeparableConv2D name=block2_sepconv2, built=True>,
#  <BatchNormalization name=block2_sepconv2_bn, built=True>,
#  <Conv2D name=block2_residual_conv, built=True>,
#  <MaxPooling2D name=block2_pool, built=True>,
#  <BatchNormalization name=block2_residual_bn, built=True>,
#  <Add name=block2_residual_add, built=True>,
#  <Activation name=block3_sepconv1_act, built=True>,
#  <SeparableConv2D name=block3_sepconv1, built=True>,
#  <BatchNormalization name=block3_sepconv1_bn, built=True>,
#  <Activation name=block3_sepconv2_act, built=True>,
#  <SeparableConv2D name=block3_sepconv2, built=True>,
#  <BatchNormalization name=block3_sepconv2_bn, built=True>,
#  <Conv2D name=block3_residual_conv, built=True>,
#  <MaxPooling2D name=block3_pool, built=True>,
#  <BatchNormalization name=block3_residual_bn, built=True>,
#  <Add name=block3_residual_add, built=True>,
#  <Activation name=block4_sepconv1_act, built=True>,
#  <SeparableConv2D name=block4_sepconv1, built=True>,
#  <BatchNormalization name=block4_sepconv1_bn, built=True>,
#  <Activation name=block4_sepconv2_act, built=True>,
#  <SeparableConv2D name=block4_sepconv2, built=True>,
#  <BatchNormalization name=block4_sepconv2_bn, built=True>,
#  <Conv2D name=block4_residual_conv, built=True>,
#  <MaxPooling2D name=block4_pool, built=True>,
#  <BatchNormalization name=block4_residual_bn, built=True>,
#  <Add name=block4_residual_add, built=True>,
#  <Activation name=block5_sepconv1_act, built=True>,
#  <SeparableConv2D name=block5_sepconv1, built=True>,
#  <BatchNormalization name=block5_sepconv1_bn, built=True>,
#  <Activation name=block5_sepconv2_act, built=True>,
#  <SeparableConv2D name=block5_sepconv2, built=True>,
#  <BatchNormalization name=block5_sepconv2_bn, built=True>,
#  <Activation name=block5_sepconv3_act, built=True>,
#  <SeparableConv2D name=block5_sepconv3, built=True>,
#  <BatchNormalization name=block5_sepconv3_bn, built=True>,
#  <Add name=block5_residual_add, built=True>,
#  <Activation name=block6_sepconv1_act, built=True>,
#  <SeparableConv2D name=block6_sepconv1, built=True>,
#  <BatchNormalization name=block6_sepconv1_bn, built=True>,
#  <Activation name=block6_sepconv2_act, built=True>,
#  <SeparableConv2D name=block6_sepconv2, built=True>,
#  <BatchNormalization name=block6_sepconv2_bn, built=True>,
#  <Activation name=block6_sepconv3_act, built=True>,
#  <SeparableConv2D name=block6_sepconv3, built=True>,
#  <BatchNormalization name=block6_sepconv3_bn, built=True>,
#  <Add name=block6_residual_add, built=True>,
#  <Activation name=block7_sepconv1_act, built=True>,
#  <SeparableConv2D name=block7_sepconv1, built=True>,
#  <BatchNormalization name=block7_sepconv1_bn, built=True>,
#  <Activation name=block7_sepconv2_act, built=True>,
#  <SeparableConv2D name=block7_sepconv2, built=True>,
#  <BatchNormalization name=block7_sepconv2_bn, built=True>,
#  <Activation name=block7_sepconv3_act, built=True>,
#  <SeparableConv2D name=block7_sepconv3, built=True>,
#  <BatchNormalization name=block7_sepconv3_bn, built=True>,
#  <Add name=block7_residual_add, built=True>,
#  <Activation name=block8_sepconv1_act, built=True>,
#  <SeparableConv2D name=block8_sepconv1, built=True>,
#  <BatchNormalization name=block8_sepconv1_bn, built=True>,
#  <Activation name=block8_sepconv2_act, built=True>,
#  <SeparableConv2D name=block8_sepconv2, built=True>,
#  <BatchNormalization name=block8_sepconv2_bn, built=True>,
#  <Activation name=block8_sepconv3_act, built=True>,
#  <SeparableConv2D name=block8_sepconv3, built=True>,
#  <BatchNormalization name=block8_sepconv3_bn, built=True>,
#  <Add name=block8_residual_add, built=True>,
#  <Activation name=block9_sepconv1_act, built=True>,
#  <SeparableConv2D name=block9_sepconv1, built=True>,
#  <BatchNormalization name=block9_sepconv1_bn, built=True>,
#  <Activation name=block9_sepconv2_act, built=True>,
#  <SeparableConv2D name=block9_sepconv2, built=True>,
#  <BatchNormalization name=block9_sepconv2_bn, built=True>,
#  <Activation name=block9_sepconv3_act, built=True>,
#  <SeparableConv2D name=block9_sepconv3, built=True>,
#  <BatchNormalization name=block9_sepconv3_bn, built=True>,
#  <Add name=block9_residual_add, built=True>,
#  <Activation name=block10_sepconv1_act, built=True>,
#  <SeparableConv2D name=block10_sepconv1, built=True>,
#  <BatchNormalization name=block10_sepconv1_bn, built=True>,
#  <Activation name=block10_sepconv2_act, built=True>,
#  <SeparableConv2D name=block10_sepconv2, built=True>,
#  <BatchNormalization name=block10_sepconv2_bn, built=True>,
#  <Activation name=block10_sepconv3_act, built=True>,
#  <SeparableConv2D name=block10_sepconv3, built=True>,
#  <BatchNormalization name=block10_sepconv3_bn, built=True>,
#  <Add name=block10_residual_add, built=True>,
#  <Activation name=block11_sepconv1_act, built=True>,
#  <SeparableConv2D name=block11_sepconv1, built=True>,
#  <BatchNormalization name=block11_sepconv1_bn, built=True>,
#  <Activation name=block11_sepconv2_act, built=True>,
#  <SeparableConv2D name=block11_sepconv2, built=True>,
#  <BatchNormalization name=block11_sepconv2_bn, built=True>,
#  <Activation name=block11_sepconv3_act, built=True>,
#  <SeparableConv2D name=block11_sepconv3, built=True>,
#  <BatchNormalization name=block11_sepconv3_bn, built=True>,
#  <Add name=block11_residual_add, built=True>,
#  <Activation name=block12_sepconv1_act, built=True>,
#  <SeparableConv2D name=block12_sepconv1, built=True>,
#  <BatchNormalization name=block12_sepconv1_bn, built=True>,
#  <Activation name=block12_sepconv2_act, built=True>,
#  <SeparableConv2D name=block12_sepconv2, built=True>,
#  <BatchNormalization name=block12_sepconv2_bn, built=True>,
#  <Activation name=block12_sepconv3_act, built=True>,
#  <SeparableConv2D name=block12_sepconv3, built=True>,
#  <BatchNormalization name=block12_sepconv3_bn, built=True>,
#  <Add name=block12_residual_add, built=True>,
#  <Activation name=block13_sepconv1_act, built=True>,
#  <SeparableConv2D name=block13_sepconv1, built=True>,
#  <BatchNormalization name=block13_sepconv1_bn, built=True>,
#  <Activation name=block13_sepconv2_act, built=True>,
#  <SeparableConv2D name=block13_sepconv2, built=True>,
#  <BatchNormalization name=block13_sepconv2_bn, built=True>,
#  <Conv2D name=block13_residual_conv, built=True>,
#  <MaxPooling2D name=block13_pool, built=True>,
#  <BatchNormalization name=block13_residual_bn, built=True>,
#  <Add name=block13_residual_add, built=True>,
#  <SeparableConv2D name=block14_sepconv1, built=True>,
#  <BatchNormalization name=block14_sepconv1_bn, built=True>,
#  <Activation name=block14_sepconv1_act, built=True>,
#  <SeparableConv2D name=block14_sepconv2, built=True>,
#  <BatchNormalization name=block14_sepconv2_bn, built=True>,
#  <Activation name=block14_sepconv2_act, built=True>]

# %%
for layer in model.layers:
    if isinstance(layer, (keras.layers.Conv2D, keras.layers.SeparableConv2D)):
        print(layer.name)
# Out:
# block1_conv1
# block1_conv2
# block2_sepconv1
# block2_sepconv2
# block2_residual_conv
# block3_sepconv1
# block3_sepconv2
# block3_residual_conv
# block4_sepconv1
# block4_sepconv2
# block4_residual_conv
# block5_sepconv1
# block5_sepconv2
# block5_sepconv3
# block6_sepconv1
# block6_sepconv2
# block6_sepconv3
# block7_sepconv1
# block7_sepconv2
# block7_sepconv3
# block8_sepconv1
# block8_sepconv2
# block8_sepconv3
# block9_sepconv1
# block9_sepconv2
# block9_sepconv3
# block10_sepconv1
# block10_sepconv2
# block10_sepconv3
# block11_sepconv1
# block11_sepconv2
# block11_sepconv3
# block12_sepconv1
# block12_sepconv2
# block12_sepconv3
# block13_sepconv1
# block13_sepconv2
# block13_residual_conv
# block14_sepconv1
# block14_sepconv2

# %%
layer_name = "block14_sepconv2"
layer = model.get_layer(name=layer_name)
feature_extractor = keras.Model(inputs=model.input, outputs=layer.output)
feature_extractor.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, None,      │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, None,      │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, None,      │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, None,      │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, None,      │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, None,      │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, None,      │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, None,      │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, None,      │          0 │ block2_sepconv1_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, None,      │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, None,      │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_residual_co… │ (None, None,      │      8,192 │ block1_conv2_act… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, None,      │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_residual_bn  │ (None, None,      │        512 │ block2_residual_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_residual_add │ (None, None,      │          0 │ block2_pool[0][0… │
# │ (Add)               │ None, 128)        │            │ block2_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, None,      │          0 │ block2_residual_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, None,      │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, None,      │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, None,      │          0 │ block3_sepconv1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, None,      │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, None,      │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_residual_co… │ (None, None,      │     32,768 │ block2_residual_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, None,      │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_residual_bn  │ (None, None,      │      1,024 │ block3_residual_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_residual_add │ (None, None,      │          0 │ block3_pool[0][0… │
# │ (Add)               │ None, 256)        │            │ block3_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, None,      │          0 │ block3_residual_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, None,      │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, None,      │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, None,      │          0 │ block4_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, None,      │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, None,      │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_residual_co… │ (None, None,      │    186,368 │ block3_residual_… │
# │ (Conv2D)            │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, None,      │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_residual_bn  │ (None, None,      │      2,912 │ block4_residual_… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_residual_add │ (None, None,      │          0 │ block4_pool[0][0… │
# │ (Add)               │ None, 728)        │            │ block4_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, None,      │          0 │ block4_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, None,      │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, None,      │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, None,      │          0 │ block5_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, None,      │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, None,      │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, None,      │          0 │ block5_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, None,      │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, None,      │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_residual_add │ (None, None,      │          0 │ block5_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block4_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, None,      │          0 │ block5_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, None,      │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, None,      │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, None,      │          0 │ block6_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, None,      │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, None,      │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, None,      │          0 │ block6_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, None,      │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, None,      │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_residual_add │ (None, None,      │          0 │ block6_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block5_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, None,      │          0 │ block6_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, None,      │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, None,      │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, None,      │          0 │ block7_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, None,      │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, None,      │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, None,      │          0 │ block7_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, None,      │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, None,      │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_residual_add │ (None, None,      │          0 │ block7_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block6_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, None,      │          0 │ block7_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, None,      │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, None,      │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, None,      │          0 │ block8_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, None,      │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, None,      │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, None,      │          0 │ block8_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, None,      │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, None,      │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_residual_add │ (None, None,      │          0 │ block8_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block7_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, None,      │          0 │ block8_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, None,      │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, None,      │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, None,      │          0 │ block9_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, None,      │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, None,      │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, None,      │          0 │ block9_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, None,      │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, None,      │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_residual_add │ (None, None,      │          0 │ block9_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block8_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, None,      │          0 │ block9_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, None,      │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, None,      │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, None,      │          0 │ block10_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, None,      │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, None,      │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, None,      │          0 │ block10_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, None,      │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, None,      │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_residual_a… │ (None, None,      │          0 │ block10_sepconv3… │
# │ (Add)               │ None, 728)        │            │ block9_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, None,      │          0 │ block10_residual… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, None,      │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, None,      │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, None,      │          0 │ block11_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, None,      │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, None,      │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, None,      │          0 │ block11_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, None,      │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, None,      │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_residual_a… │ (None, None,      │          0 │ block11_sepconv3… │
# │ (Add)               │ None, 728)        │            │ block10_residual… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, None,      │          0 │ block11_residual… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, None,      │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, None,      │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, None,      │          0 │ block12_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, None,      │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, None,      │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, None,      │          0 │ block12_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, None,      │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, None,      │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_residual_a… │ (None, None,      │          0 │ block12_sepconv3… │
# │ (Add)               │ None, 728)        │            │ block11_residual… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, None,      │          0 │ block12_residual… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, None,      │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, None,      │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, None,      │          0 │ block13_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, None,      │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, None,      │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_residual_c… │ (None, None,      │    745,472 │ block12_residual… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, None,      │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_residual_bn │ (None, None,      │      4,096 │ block13_residual… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_residual_a… │ (None, None,      │          0 │ block13_pool[0][… │
# │ (Add)               │ None, 1024)       │            │ block13_residual… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, None,      │  1,582,080 │ block13_residual… │
# │ (SeparableConv2D)   │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, None,      │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, None,      │          0 │ block14_sepconv1… │
# │ (Activation)        │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, None,      │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ None, 2048)       │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,853,288 (79.55 MB)
#  Trainable params: 20,802,856 (79.36 MB)
#  Non-trainable params: 50,432 (197.00 KB)

# %%
activation = feature_extractor(preprocessor(img_tensor))
activation
# Out:
# <tf.Tensor: shape=(1, 6, 6, 2048), dtype=float32, numpy=
# array([[[[-0.28398708, -0.18485768, -0.18907489, ..., -0.24653009,
#           -0.2573037 , -0.26416874],
#          [-0.3672667 , -0.1552059 , -0.18779023, ..., -0.2951949 ,
#           -0.32176363, -0.31242386],
#          [-0.38521162, -0.18610214, -0.1676375 , ..., -0.34244916,
#           -0.3615303 , -0.30210674],
#          [-0.36088195, -0.21589153, -0.19289686, ..., -0.3867638 ,
#           -0.3576159 , -0.2658834 ],
#          [-0.3533332 , -0.27825245, -0.22839566, ..., -0.4431342 ,
#           -0.3342241 , -0.2727826 ],
#          [-0.28586903, -0.23398656, -0.22086462, ..., -0.3562778 ,
#           -0.2585257 , -0.21868277]],
#
#         [[-0.3559166 , -0.1781765 , -0.19866034, ..., -0.31005973,
#           -0.35562083, -0.27323043],
#          [-0.4615837 , -0.10569561, -0.17241293, ..., -0.3584982 ,
#           -0.44483924, -0.270045  ],
#          [-0.5293156 , -0.1750516 , -0.17214794, ..., -0.42908916,
#           -0.516477  , -0.24662523],
#          [-0.5036611 , -0.24902904, -0.22679162, ..., -0.4907494 ,
#           -0.50417244, -0.19178951],
#          [-0.4858039 , -0.35891783, -0.25806475, ..., -0.5728642 ,
#           -0.46032554, -0.24323396],
#          [-0.3764231 , -0.28953418, -0.24638437, ..., -0.46308672,
#           -0.34443596, -0.21475792]],
#
#         [[-0.36962792, -0.18607229, -0.16259047, ..., -0.3186116 ,
#           -0.40981933, -0.21148944],
#          [-0.50306195, -0.1265206 , -0.15163691, ..., -0.4222931 ,
#           -0.5470412 , -0.1964526 ],
#          [-0.67208064, -0.22335346, -0.1813083 , ..., -0.6147967 ,
#           -0.72550833, -0.24498294],
#          [-0.64671403, -0.29782903, -0.27137256, ..., -0.6980347 ,
#           -0.7224162 , -0.228339  ],
#          [-0.6239262 , -0.43625182, -0.28287748, ..., -0.81167054,
#           -0.7115965 , -0.3223926 ],
#          [-0.43308327, -0.32797545, -0.2429613 , ..., -0.58081985,
#           -0.48117012, -0.26470816]],
#
#         [[-0.33315924, -0.23386645, -0.14599098, ..., -0.38403815,
#           -0.42841023, -0.19178183],
#          [-0.4618253 , -0.20405926, -0.13254187, ..., -0.522136  ,
#           -0.5932525 , -0.17098081],
#          [-0.65782714, -0.2629518 , -0.15951066, ..., -0.6853644 ,
#           -0.7420382 , -0.24162954],
#          [-0.6430106 , -0.34452826, -0.26312244, ..., -0.77051955,
#           -0.7796604 , -0.24250232],
#          [-0.6388971 , -0.50857264, -0.29172438, ..., -0.896836  ,
#           -0.79092604, -0.37520072],
#          [-0.4505187 , -0.40190613, -0.25958666, ..., -0.6611046 ,
#           -0.5685444 , -0.31302676]],
#
#         [[-0.3069259 , -0.32825035, -0.17904195, ..., -0.44476786,
#           -0.44632983, -0.22117494],
#          [-0.42285803, -0.31855646, -0.16288003, ..., -0.5954931 ,
#           -0.59296066, -0.21993291],
#          [-0.6149626 , -0.31123707, -0.15682843, ..., -0.77111256,
#           -0.7236645 , -0.33351266],
#          [-0.62424463, -0.34552634, -0.2478363 , ..., -0.8521477 ,
#           -0.7692058 , -0.36345357],
#          [-0.6161436 , -0.47765303, -0.30150193, ..., -0.9808927 ,
#           -0.78794473, -0.4935575 ],
#          [-0.44203076, -0.40347105, -0.29112718, ..., -0.71985096,
#           -0.58285224, -0.3990594 ]],
#
#         [[-0.25053543, -0.29059383, -0.17932184, ..., -0.38337275,
#           -0.35690445, -0.20658633],
#          [-0.3255702 , -0.29287717, -0.15364149, ..., -0.50158626,
#           -0.45843416, -0.21443334],
#          [-0.40923417, -0.2534502 , -0.11006973, ..., -0.5636002 ,
#           -0.48896646, -0.2683834 ],
#          [-0.41414878, -0.27157253, -0.16040929, ..., -0.6089779 ,
#           -0.5188234 , -0.2865386 ],
#          [-0.40653345, -0.35703975, -0.22575323, ..., -0.6637625 ,
#           -0.5163256 , -0.37052393],
#          [-0.30857858, -0.30511674, -0.23563658, ..., -0.50661904,
#           -0.40177777, -0.30402628]]]],
#       shape=(1, 6, 6, 2048), dtype=float32)>

# %% [markdown]
# ### Gradients

# %%
def compute_loss(image, filter_index):
    activation = feature_extractor(image)
    filter_activation = activation[:, 2:-2, 2:-2, filter_index]
    return keras.ops.mean(filter_activation)

# %%
@tf.function
def gradient_ascent_step(image, filter_index, learning_rate):
    with tf.GradientTape() as tape:
        tape.watch(image)
        loss = compute_loss(image, filter_index)
    grads = tape.gradient(loss, image)
    grads = keras.ops.normalize(grads)
    image += learning_rate * grads
    return image

# %% [markdown]
# ### Viz Filters

# %%
img_width = 200
img_height = 200
def generate_filter_pattern(filter_index):
    iterations = 30
    learning_rate = 10.0
    image = keras.random.uniform(
        minval=0.4, maxval=0.6, shape=(1, img_width, img_height, 3)
    )
    for i in range(iterations):
        image = gradient_ascent_step(image, filter_index, learning_rate)
    return image[0]

# %%
def deprocess_image(image):
    image -= keras.ops.mean(image)
    image /= keras.ops.std(image)
    image *= 64
    image += 128
    image = keras.ops.clip(image, 0, 255)
    image = image[25:-25, 25:-25, :]
    image = keras.ops.cast(image, dtype="uint8")
    return keras.ops.convert_to_numpy(image)

# %%
plt.axis("off")
plt.imshow(deprocess_image(generate_filter_pattern(filter_index=2)))

# %%
all_images = []
for filter_index in range(64):
    print(f"Processing filter {filter_index}")
    image = deprocess_image(generate_filter_pattern(filter_index))
    all_images.append(image)


margin = 5
n = 8
box_width = img_width - 25 * 2
box_height = img_height - 25 * 2
full_width = n * box_width + (n - 1) * margin
full_height = n * box_height + (n - 1) * margin
stitched_filters = np.zeros((full_width, full_height, 3))
for i in range(n):
    for j in range(n):
        image = all_images[i * n + j]
        stitched_filters[
    (box_width + margin) * i : (box_width + margin) * i + box_width,
    (box_height + margin) * j : (box_height + margin) * j + box_height,:,] = image
keras.utils.save_img(f"filters_for_layer_{layer_name}.png", stitched_filters)
# Out:
# Processing filter 0
# Processing filter 1
# Processing filter 2
# Processing filter 3
# Processing filter 4
# Processing filter 5
# Processing filter 6
# Processing filter 7
# Processing filter 8
# Processing filter 9
# Processing filter 10
# Processing filter 11
# Processing filter 12
# Processing filter 13
# Processing filter 14
# Processing filter 15
# Processing filter 16
# Processing filter 17
# Processing filter 18
# Processing filter 19
# Processing filter 20
# Processing filter 21
# Processing filter 22
# Processing filter 23
# Processing filter 24
# Processing filter 25
# Processing filter 26
# Processing filter 27
# Processing filter 28
# Processing filter 29
# Processing filter 30
# Processing filter 31
# Processing filter 32
# Processing filter 33
# Processing filter 34
# Processing filter 35
# Processing filter 36
# Processing filter 37
# Processing filter 38
# Processing filter 39
# Processing filter 40
# Processing filter 41
# Processing filter 42
# Processing filter 43
# Processing filter 44
# Processing filter 45
# Processing filter 46
# Processing filter 47
# Processing filter 48
# Processing filter 49
# Processing filter 50
# Processing filter 51
# Processing filter 52
# Processing filter 53
# Processing filter 54
# Processing filter 55
# Processing filter 56
# Processing filter 57
# Processing filter 58
# Processing filter 59
# Processing filter 60
# Processing filter 61
# Processing filter 62
# Processing filter 63
