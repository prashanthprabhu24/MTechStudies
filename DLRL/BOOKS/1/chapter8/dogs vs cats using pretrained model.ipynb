# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
import pathlib
import keras_hub

# %%
# Quick health check to prove it works:
print("Is PyTorch utilizing the GPU?:", torch.cuda.is_available())
print("Device Name:", torch.cuda.get_device_name(0))
# Out:
# Is PyTorch utilizing the GPU?: True
# Device Name: NVIDIA GeForce RTX 5050 Laptop GPU

# %% [markdown]
# ### Load Dataset

# %%
batch_size = 16
image_size = (180, 180)
new_base_dir = pathlib.Path("dogs_vs_cats_small")

# %%
train_dataset = keras.utils.image_dataset_from_directory(new_base_dir / "train", image_size=image_size, batch_size=batch_size)
validation_dataset = keras.utils.image_dataset_from_directory(new_base_dir / "validation", image_size=image_size, batch_size=batch_size)
test_dataset = keras.utils.image_dataset_from_directory(new_base_dir / "test", image_size=image_size, batch_size=batch_size)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
data_augmentation_layers = [
    keras.layers.RandomFlip("horizontal"),
    keras.layers.RandomRotation(0.1),
    keras.layers.RandomZoom(0.2),
]

def data_augmentation(images, targets):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images, targets

augmented_train_dataset = train_dataset.map(data_augmentation, num_parallel_calls=8)
augmented_train_dataset = augmented_train_dataset.prefetch(tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(10, 10))
for image_batch, _ in train_dataset.take(1):
    image = image_batch[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image, _ = data_augmentation(image, None)
        augmented_image = keras.ops.convert_to_numpy(augmented_image)
        plt.imshow(augmented_image.astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ### Load Model

# %%
# Instantiating the Xception convolutional base
conv_base = keras_hub.models.Backbone.from_preset("xception_41_imagenet")

# %%
conv_base.summary()
# Out:
# Model: "xception_backbone"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, None,      │        864 │ input_layer[0][0] │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_bn     │ (None, None,      │        128 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1_act    │ (None, None,      │          0 │ block1_conv1_bn[… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, None,      │     18,432 │ block1_conv1_act… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_bn     │ (None, None,      │        256 │ block1_conv2[0][… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2_act    │ (None, None,      │          0 │ block1_conv2_bn[… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1     │ (None, None,      │      8,768 │ block1_conv2_act… │
# │ (SeparableConv2D)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv1_bn  │ (None, None,      │        512 │ block2_sepconv1[… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_act │ (None, None,      │          0 │ block2_sepconv1_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2     │ (None, None,      │     17,536 │ block2_sepconv2_… │
# │ (SeparableConv2D)   │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_sepconv2_bn  │ (None, None,      │        512 │ block2_sepconv2[… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_residual_co… │ (None, None,      │      8,192 │ block1_conv2_act… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, None,      │          0 │ block2_sepconv2_… │
# │ (MaxPooling2D)      │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_residual_bn  │ (None, None,      │        512 │ block2_residual_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_residual_add │ (None, None,      │          0 │ block2_pool[0][0… │
# │ (Add)               │ None, 128)        │            │ block2_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_act │ (None, None,      │          0 │ block2_residual_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1     │ (None, None,      │     33,920 │ block3_sepconv1_… │
# │ (SeparableConv2D)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv1_bn  │ (None, None,      │      1,024 │ block3_sepconv1[… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_act │ (None, None,      │          0 │ block3_sepconv1_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2     │ (None, None,      │     67,840 │ block3_sepconv2_… │
# │ (SeparableConv2D)   │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_sepconv2_bn  │ (None, None,      │      1,024 │ block3_sepconv2[… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_residual_co… │ (None, None,      │     32,768 │ block2_residual_… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, None,      │          0 │ block3_sepconv2_… │
# │ (MaxPooling2D)      │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_residual_bn  │ (None, None,      │      1,024 │ block3_residual_… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_residual_add │ (None, None,      │          0 │ block3_pool[0][0… │
# │ (Add)               │ None, 256)        │            │ block3_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_act │ (None, None,      │          0 │ block3_residual_… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1     │ (None, None,      │    188,672 │ block4_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv1_bn  │ (None, None,      │      2,912 │ block4_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_act │ (None, None,      │          0 │ block4_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2     │ (None, None,      │    536,536 │ block4_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_sepconv2_bn  │ (None, None,      │      2,912 │ block4_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_residual_co… │ (None, None,      │    186,368 │ block3_residual_… │
# │ (Conv2D)            │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, None,      │          0 │ block4_sepconv2_… │
# │ (MaxPooling2D)      │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_residual_bn  │ (None, None,      │      2,912 │ block4_residual_… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_residual_add │ (None, None,      │          0 │ block4_pool[0][0… │
# │ (Add)               │ None, 728)        │            │ block4_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_act │ (None, None,      │          0 │ block4_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1     │ (None, None,      │    536,536 │ block5_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv1_bn  │ (None, None,      │      2,912 │ block5_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_act │ (None, None,      │          0 │ block5_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2     │ (None, None,      │    536,536 │ block5_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv2_bn  │ (None, None,      │      2,912 │ block5_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_act │ (None, None,      │          0 │ block5_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3     │ (None, None,      │    536,536 │ block5_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_sepconv3_bn  │ (None, None,      │      2,912 │ block5_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_residual_add │ (None, None,      │          0 │ block5_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block4_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_act │ (None, None,      │          0 │ block5_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1     │ (None, None,      │    536,536 │ block6_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv1_bn  │ (None, None,      │      2,912 │ block6_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_act │ (None, None,      │          0 │ block6_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2     │ (None, None,      │    536,536 │ block6_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv2_bn  │ (None, None,      │      2,912 │ block6_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_act │ (None, None,      │          0 │ block6_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3     │ (None, None,      │    536,536 │ block6_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_sepconv3_bn  │ (None, None,      │      2,912 │ block6_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6_residual_add │ (None, None,      │          0 │ block6_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block5_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_act │ (None, None,      │          0 │ block6_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1     │ (None, None,      │    536,536 │ block7_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv1_bn  │ (None, None,      │      2,912 │ block7_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_act │ (None, None,      │          0 │ block7_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2     │ (None, None,      │    536,536 │ block7_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv2_bn  │ (None, None,      │      2,912 │ block7_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_act │ (None, None,      │          0 │ block7_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3     │ (None, None,      │    536,536 │ block7_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_sepconv3_bn  │ (None, None,      │      2,912 │ block7_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7_residual_add │ (None, None,      │          0 │ block7_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block6_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_act │ (None, None,      │          0 │ block7_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1     │ (None, None,      │    536,536 │ block8_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv1_bn  │ (None, None,      │      2,912 │ block8_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_act │ (None, None,      │          0 │ block8_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2     │ (None, None,      │    536,536 │ block8_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv2_bn  │ (None, None,      │      2,912 │ block8_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_act │ (None, None,      │          0 │ block8_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3     │ (None, None,      │    536,536 │ block8_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_sepconv3_bn  │ (None, None,      │      2,912 │ block8_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block8_residual_add │ (None, None,      │          0 │ block8_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block7_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_act │ (None, None,      │          0 │ block8_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1     │ (None, None,      │    536,536 │ block9_sepconv1_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv1_bn  │ (None, None,      │      2,912 │ block9_sepconv1[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_act │ (None, None,      │          0 │ block9_sepconv1_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2     │ (None, None,      │    536,536 │ block9_sepconv2_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv2_bn  │ (None, None,      │      2,912 │ block9_sepconv2[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_act │ (None, None,      │          0 │ block9_sepconv2_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3     │ (None, None,      │    536,536 │ block9_sepconv3_… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_sepconv3_bn  │ (None, None,      │      2,912 │ block9_sepconv3[… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block9_residual_add │ (None, None,      │          0 │ block9_sepconv3_… │
# │ (Add)               │ None, 728)        │            │ block8_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_a… │ (None, None,      │          0 │ block9_residual_… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1    │ (None, None,      │    536,536 │ block10_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv1_bn │ (None, None,      │      2,912 │ block10_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_a… │ (None, None,      │          0 │ block10_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2    │ (None, None,      │    536,536 │ block10_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv2_bn │ (None, None,      │      2,912 │ block10_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_a… │ (None, None,      │          0 │ block10_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3    │ (None, None,      │    536,536 │ block10_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_sepconv3_bn │ (None, None,      │      2,912 │ block10_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block10_residual_a… │ (None, None,      │          0 │ block10_sepconv3… │
# │ (Add)               │ None, 728)        │            │ block9_residual_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_a… │ (None, None,      │          0 │ block10_residual… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1    │ (None, None,      │    536,536 │ block11_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv1_bn │ (None, None,      │      2,912 │ block11_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_a… │ (None, None,      │          0 │ block11_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2    │ (None, None,      │    536,536 │ block11_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv2_bn │ (None, None,      │      2,912 │ block11_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_a… │ (None, None,      │          0 │ block11_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3    │ (None, None,      │    536,536 │ block11_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_sepconv3_bn │ (None, None,      │      2,912 │ block11_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block11_residual_a… │ (None, None,      │          0 │ block11_sepconv3… │
# │ (Add)               │ None, 728)        │            │ block10_residual… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_a… │ (None, None,      │          0 │ block11_residual… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1    │ (None, None,      │    536,536 │ block12_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv1_bn │ (None, None,      │      2,912 │ block12_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_a… │ (None, None,      │          0 │ block12_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2    │ (None, None,      │    536,536 │ block12_sepconv2… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv2_bn │ (None, None,      │      2,912 │ block12_sepconv2… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_a… │ (None, None,      │          0 │ block12_sepconv2… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3    │ (None, None,      │    536,536 │ block12_sepconv3… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_sepconv3_bn │ (None, None,      │      2,912 │ block12_sepconv3… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block12_residual_a… │ (None, None,      │          0 │ block12_sepconv3… │
# │ (Add)               │ None, 728)        │            │ block11_residual… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_a… │ (None, None,      │          0 │ block12_residual… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1    │ (None, None,      │    536,536 │ block13_sepconv1… │
# │ (SeparableConv2D)   │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv1_bn │ (None, None,      │      2,912 │ block13_sepconv1… │
# │ (BatchNormalizatio… │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_a… │ (None, None,      │          0 │ block13_sepconv1… │
# │ (Activation)        │ None, 728)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2    │ (None, None,      │    752,024 │ block13_sepconv2… │
# │ (SeparableConv2D)   │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_sepconv2_bn │ (None, None,      │      4,096 │ block13_sepconv2… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_residual_c… │ (None, None,      │    745,472 │ block12_residual… │
# │ (Conv2D)            │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_pool        │ (None, None,      │          0 │ block13_sepconv2… │
# │ (MaxPooling2D)      │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_residual_bn │ (None, None,      │      4,096 │ block13_residual… │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block13_residual_a… │ (None, None,      │          0 │ block13_pool[0][… │
# │ (Add)               │ None, 1024)       │            │ block13_residual… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1    │ (None, None,      │  1,582,080 │ block13_residual… │
# │ (SeparableConv2D)   │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_bn │ (None, None,      │      6,144 │ block14_sepconv1… │
# │ (BatchNormalizatio… │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv1_a… │ (None, None,      │          0 │ block14_sepconv1… │
# │ (Activation)        │ None, 1536)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2    │ (None, None,      │  3,159,552 │ block14_sepconv1… │
# │ (SeparableConv2D)   │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_bn │ (None, None,      │      8,192 │ block14_sepconv2… │
# │ (BatchNormalizatio… │ None, 2048)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block14_sepconv2_a… │ (None, None,      │          0 │ block14_sepconv2… │
# │ (Activation)        │ None, 2048)       │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,861,480 (79.58 MB)
#  Trainable params: 20,806,952 (79.37 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
# Instantiating the preprocessing paired with the Xception model
# preprocessor = keras_cv.layers.ImageConverter.from_preset("xception_41_imagenet",image_size=(180, 180))

# equivalent of KerasHub's Xception preprocessor does:
preprocessor = keras.Sequential([
    keras.layers.Resizing(180, 180, interpolation="bilinear", crop_to_aspect_ratio=True),
    keras.layers.Rescaling(scale=1.0 / 127.5, offset=-1.0)
])

# %% [markdown]
# ### Using Pretrained Model for feature extraction

# %%
# Extracting the image features and corresponding labels
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = preprocessor(images)
        features = conv_base.predict(preprocessed_images, verbose=0)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

# %%
train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)
# Out:
# Exception ignored in: <function _xla_gc_callback at 0x000002334793DD00>
# Traceback (most recent call last):
#   File "C:\Users\PRASHANTH N\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\jax\_src\lib\__init__.py", line 122, in _xla_gc_callback
#     def _xla_gc_callback(*args):
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 train_features, train_labels = get_features_and_labels(train_dataset)
#       2 val_features, val_labels = get_features_and_labels(validation_dataset)
#       3 test_features, test_labels = get_features_and_labels(test_dataset)
#
# Cell In[11], line 7, in get_features_and_labels(dataset)
#       3     all_features = []
#       4     all_labels = []
#       5     for images, labels in dataset:
#       6         preprocessed_images = preprocessor(images)
# ----> 7         features = conv_base.predict(preprocessed_images, verbose=0)
#       8         all_features.append(features)
#       9         all_labels.append(labels)
#      10     return np.concatenate(all_features), np.concatenate(all_labels)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\backend\torch\trainer.py:445, in TorchTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     443 for begin_step, end_step, data in epoch_iterator:
#     444     callbacks.on_predict_batch_begin(begin_step)
# --> 445     batch_outputs = self.predict_function(data)
#     446     outputs = append_to_outputs(batch_outputs, outputs)
#     447     callbacks.on_predict_batch_end(end_step, {"outputs": batch_outputs})
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\backend\torch\trainer.py:167, in TorchTrainer.make_predict_function.<locals>.one_step_on_data(data)
#     165 data = data[0]
#     166 with torch.no_grad():
# --> 167     return self.predict_step(data)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\backend\torch\trainer.py:107, in TorchTrainer.predict_step(self, data)
#     105 x, _, _ = data_adapter_utils.unpack_x_y_sample_weight(data)
#     106 if self._call_has_training_arg:
# --> 107     y_pred = self(x, training=False)
#     108 else:
#     109     y_pred = self(x)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\layers\layer.py:998, in Layer.__call__(self, *args, **kwargs)
#     996         outputs = super().__call__(*args, **kwargs)
#     997 else:
# --> 998     outputs = super().__call__(*args, **kwargs)
#     999 # Change the layout for the layer output if needed.
#    1000 # This is useful for relayout intermediate tensor in the model
#    1001 # to achieve the optimal performance.
#    1002 distribution = distribution_lib.distribution()
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\backend\torch\layer.py:41, in TorchLayer.forward(self, *args, **kwargs)
#      40 def forward(self, *args, **kwargs):
# ---> 41     return Operation.__call__(self, *args, **kwargs)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\ops\operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\models\functional.py:183, in Functional.call(self, inputs, training, mask, **kwargs)
#     181         if mask is not None:
#     182             backend.set_keras_mask(x, mask)
# --> 183 outputs = self._run_through_graph(
#     184     inputs,
#     185     operation_fn=lambda op: operation_fn(
#     186         op, training=training, **kwargs
#     187     ),
#     188 )
#     189 return unpack_singleton(outputs)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\ops\function.py:210, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     208     operation = self._get_operation_for_node(node)
#     209     op = operation_fn(operation)
# --> 210     outputs = op(*args, **kwargs)
#     212 # Update tensor_dict.
#     213 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\models\functional.py:706, in operation_fn.<locals>.call(*args, **kwargs)
#     700     if (
#     701         name in getattr(operation, "_call_context_args", {})
#     702         and value is not None
#     703     ):
#     704         kwargs[name] = value
# --> 706 return operation(*args, **kwargs)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\layers\layer.py:998, in Layer.__call__(self, *args, **kwargs)
#     996         outputs = super().__call__(*args, **kwargs)
#     997 else:
# --> 998     outputs = super().__call__(*args, **kwargs)
#     999 # Change the layout for the layer output if needed.
#    1000 # This is useful for relayout intermediate tensor in the model
#    1001 # to achieve the optimal performance.
#    1002 distribution = distribution_lib.distribution()
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\backend\torch\layer.py:41, in TorchLayer.forward(self, *args, **kwargs)
#      40 def forward(self, *args, **kwargs):
# ---> 41     return Operation.__call__(self, *args, **kwargs)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\ops\operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\layers\convolutional\base_separable_conv.py:218, in BaseSeparableConv.call(self, inputs)
#     217 def call(self, inputs):
# --> 218     outputs = ops.separable_conv(
#     219         inputs,
#     220         self.depthwise_kernel,
#     221         self.pointwise_kernel,
#     222         strides=self.strides,
#     223         padding=self.padding,
#     224         dilation_rate=self.dilation_rate,
#     225         data_format=self.data_format,
#     226     )
#     228     if self.use_bias:
#     229         if self.data_format == "channels_last":
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\ops\nn.py:1741, in separable_conv(inputs, depthwise_kernel, pointwise_kernel, strides, padding, data_format, dilation_rate)
#    1734 if any_symbolic_tensors((inputs,)):
#    1735     return SeparableConv(
#    1736         strides,
#    1737         padding,
#    1738         data_format,
#    1739         dilation_rate,
#    1740     ).symbolic_call(inputs, depthwise_kernel, pointwise_kernel)
# -> 1741 return backend.nn.separable_conv(
#    1742     inputs,
#    1743     depthwise_kernel,
#    1744     pointwise_kernel,
#    1745     strides,
#    1746     padding,
#    1747     data_format,
#    1748     dilation_rate,
#    1749 )
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\backend\torch\nn.py:683, in separable_conv(inputs, depthwise_kernel, pointwise_kernel, strides, padding, data_format, dilation_rate)
#     666 def separable_conv(
#     667     inputs,
#     668     depthwise_kernel,
#    (...)    673     dilation_rate=1,
#     674 ):
#     675     depthwise_conv_output = depthwise_conv(
#     676         inputs,
#     677         depthwise_kernel,
#    (...)    681         dilation_rate,
#     682     )
# --> 683     return conv(
#     684         depthwise_conv_output,
#     685         pointwise_kernel,
#     686         strides=1,
#     687         padding="valid",
#     688         data_format=data_format,
#     689         dilation_rate=dilation_rate,
#     690     )
#
# File ~\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\keras\src\backend\torch\nn.py:622, in conv(inputs, kernel, strides, padding, data_format, dilation_rate)
#     613     outputs = tnn.conv1d(
#     614         inputs,
#     615         kernel,
#    (...)    619         groups=groups,
#     620     )
#     621 elif num_spatial_dims == 2:
# --> 622     outputs = tnn.conv2d(
#     623         inputs,
#     624         kernel,
#     625         stride=strides,
#     626         padding=padding,
#     627         dilation=dilation_rate,
#     628         groups=groups,
#     629     )
#     630 elif num_spatial_dims == 3:
#     631     outputs = tnn.conv3d(
#     632         inputs,
#     633         kernel,
#    (...)    637         groups=groups,
#     638     )
#
# KeyboardInterrupt:

# %%
train_features.shape, train_labels.shape, val_features.shape, val_labels.shape, test_features.shape, test_labels.shape

# %%
# Defining and training the densely connected classifier
inputs = keras.Input(shape=(6, 6, 2048))
x = keras.layers.GlobalAveragePooling2D()(inputs)
x = keras.layers.Dense(256, activation="relu")(x)
x = keras.layers.Dropout(0.9)(x)
outputs = keras.layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]

history = model.fit(
    train_features,
    train_labels,
    epochs=10,
    validation_data=(val_features, val_labels),
    callbacks=callbacks,
)

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features, test_labels)
print(f"Test accuracy: {test_acc:.3f}")

# %% [markdown]
# ### Training on Pretrained Model

# %%
conv_base = keras_hub.models.Backbone.from_preset(
    "xception_41_imagenet",
    trainable=False,
)

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = preprocessor(inputs)
x = conv_base(x)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dense(256)(x)
x = keras.layers.Dropout(0.25)(x)
outputs = keras.layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
# Clear any previous caching and only fetch 2 batches ahead
augmented_train_dataset = augmented_train_dataset.prefetch(buffer_size=2)
validation_dataset = validation_dataset.prefetch(buffer_size=2)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# 5 min per epoch in CPU
# 1 min per epoch in GPU

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Finetune a pretrained Model

# %% [markdown]
# Steps for fine-tuning a network are as follows:
#
# 1 Add your custom network on top of an already trained base network. (Done)
#
# 2 Freeze the base network. (Done)
#
# 3 Train the part you added. (Done)
#
# 4 Unfreeze the base network. (Below)
#
# 5 Jointly train both these layers and the part you added. (Below)

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]

history = model.fit(
    augmented_train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks,
)

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
