# %%
#!pip uninstall torch torchvision torchaudio -y
#!pip cache purge
#!pip install --pre torch --index-url https://download.pytorch.org/whl/nightly/cu128
# Out:
# Found existing installation: torch 2.14.0.dev20260615+cu126
# Uninstalling torch-2.14.0.dev20260615+cu126:
#   Successfully uninstalled torch-2.14.0.dev20260615+cu126
# Found existing installation: torchvision 0.29.0.dev20260615+cu126
# Uninstalling torchvision-0.29.0.dev20260615+cu126:
#   Successfully uninstalled torchvision-0.29.0.dev20260615+cu126
# Found existing installation: torchaudio 2.11.0.dev20260615+cu126
# Uninstalling torchaudio-2.11.0.dev20260615+cu126:
#   Successfully uninstalled torchaudio-2.11.0.dev20260615+cu126
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\PRASHANTH N\PycharmProjects\MTechSem2\gpu\.venv\Lib\site-packages\~~rch'.
# You can safely remove it manually.
# Files removed: 12 (2608.3 MB)
# Directories removed: 0
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu128
# ...
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
# ...

# %%
import torch
torch.version.__version__
# Out:
# '2.12.0.dev20260408+cu128'

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

import keras
import torch


# Quick health check to prove it works:
print("Is PyTorch utilizing the GPU?:", torch.cuda.is_available())
print("Device Name:", torch.cuda.get_device_name(0))
# Out:
# Is PyTorch utilizing the GPU?: True
# Device Name: NVIDIA GeForce RTX 5050 Laptop GPU

# %%
import os
# Force Keras to use Torch
os.environ["KERAS_BACKEND"] = "torch"
# Force PyTorch to accept the RTX 5050's compute capability
os.environ["TORCH_CUDA_ARCH_LIST"] = "9.0"

import keras
import torch

print("Is PyTorch utilizing the GPU?:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device Name:", torch.cuda.get_device_name(0))
    # Test tensor allocation
    print("Allocated Tensor:", torch.zeros(1).cuda())
# Out:
# Is PyTorch utilizing the GPU?: True
# Device Name: NVIDIA GeForce RTX 5050 Laptop GPU
# Allocated Tensor: tensor([0.], device='cuda:0')
