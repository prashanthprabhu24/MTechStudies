# %% [markdown]
# ### Set Up

# %%
import torch
import torch.nn as nn
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from torch.utils.data import TensorDataset, DataLoader

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ### Load Dataset

# %%
def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
    with tarfile.open(tarball_path) as housing_tarball:
        housing_tarball.extractall(path="datasets", filter="data")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

# %%
housing_full = load_housing_data()

# %%
housing_full.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ### Data Processing

# %%
housing_full = housing_full.drop("ocean_proximity", axis=1)

# %%
imputer = SimpleImputer(strategy="median")
imputer.fit(housing_full)
# Out:
# SimpleImputer(strategy='median')

# %%
X = imputer.transform(housing_full)
housing_full = pd.DataFrame(X, columns=housing_full.columns, index=housing_full.index)

# %%
train_set, test_set = train_test_split(housing_full, test_size=0.2, random_state=42)
train_set, val_set = train_test_split(train_set, test_size=0.2, random_state=42)
housing_full.shape, train_set.shape, val_set.shape, test_set.shape
# Out:
# ((20640, 9), (13209, 9), (3303, 9), (4128, 9))

# %%
X_train, y_train = train_set.drop("median_house_value", axis=1), train_set["median_house_value"]
X_valid, y_valid = val_set.drop("median_house_value", axis=1), val_set["median_house_value"]
X_test, y_test = test_set.drop("median_house_value", axis=1), test_set["median_house_value"]

# %%
X_train = torch.tensor(X_train.to_numpy(), dtype=torch.float64, device=device)
X_valid = torch.tensor(X_valid.to_numpy(), dtype=torch.float64, device=device)
X_test = torch.tensor(X_test.to_numpy(), dtype=torch.float64, device=device)

# %%
y_train = torch.tensor(y_train.to_numpy(), dtype=torch.float64, device=device).reshape(-1, 1)
y_valid = torch.tensor(y_valid.to_numpy(), dtype=torch.float64, device=device).reshape(-1, 1)
y_test = torch.tensor(y_test.to_numpy(), dtype=torch.float64, device=device).reshape(-1, 1)

# %%
X_train
# Out:
# tensor([[-1.2129e+02,  3.8710e+01,  3.2000e+01,  ...,  1.0270e+03,
#           3.4300e+02,  3.5769e+00],
#         [-1.2138e+02,  3.8640e+01,  1.9000e+01,  ...,  2.2560e+03,
#           9.2600e+02,  2.1472e+00],
#         [-1.2129e+02,  3.8900e+01,  4.5000e+01,  ...,  1.1040e+03,
#           4.0700e+02,  3.1691e+00],
#         ...,
#         [-1.1714e+02,  3.2710e+01,  4.3000e+01,  ...,  8.5700e+02,
#           2.0800e+02,  1.2841e+00],
#         [-1.2226e+02,  3.7880e+01,  5.2000e+01,  ...,  1.7980e+03,
#           7.6900e+02,  1.7250e+00],
#         [-1.1750e+02,  3.4660e+01,  2.0000e+01,  ...,  4.8600e+02,
#           1.9600e+02,  2.0184e+00]], device='cuda:0', dtype=torch.float64)

# %%
y_train
# Out:
# tensor([[103800.],
#         [143400.],
#         [108700.],
#         ...,
#         [ 72000.],
#         [287500.],
#         [ 84900.]], device='cuda:0', dtype=torch.float64)

# %%
X_train.device, y_train.device
# Out:
# (device(type='cuda', index=0), device(type='cuda', index=0))

# %%
means = X_train.mean(dim=0, keepdims=True)
stds = X_train.std(dim=0, keepdims=True)
X_train = (X_train- means) / stds
X_valid = (X_valid- means) / stds
X_test = (X_test- means) / stds

# %%
X_train
# Out:
# tensor([[-0.8667,  1.4490,  0.2663,  ..., -0.3487, -0.4120, -0.1475],
#         [-0.9118,  1.4161, -0.7652,  ...,  0.7295,  1.1263, -0.8947],
#         [-0.8667,  1.5382,  1.2979,  ..., -0.2811, -0.2431, -0.3606],
#         ...,
#         [ 1.2113, -1.3684,  1.1392,  ..., -0.4978, -0.7682, -1.3459],
#         [-1.3525,  1.0592,  1.8533,  ...,  0.3277,  0.7121, -1.1154],
#         [ 1.0311, -0.4528, -0.6859,  ..., -0.8233, -0.7998, -0.9621]],
#        device='cuda:0', dtype=torch.float64)

# %%
ymeans = y_train.mean(dim=0, keepdims=True)
ystds = y_train.std(dim=0, keepdims=True)
y_train = (y_train- ymeans) / ystds
y_valid = (y_valid- ymeans) / ystds
y_test = (y_test- ymeans) / ystds

# %%
train_dataset = TensorDataset(X_train, y_train)
batch_size = 256
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, persistent_workers=True, num_workers=8, prefetch_factor=8)

# %% [markdown]
# ### Model

# %%
torch.manual_seed(42)
n_features = X_train.shape[1] # there are 8 input features

# %%
model = nn.Sequential(nn.Linear(n_features, 50), nn.ReLU(), nn.Linear(50, 40), nn.ReLU(), nn.Linear(40, 1))
model.to(device=device, dtype=torch.float64)
model
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=40, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=40, out_features=1, bias=True)
# )

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.2703,  0.2935, -0.0828,  0.3248, -0.0775,  0.0713, -0.1721,  0.2076],
#          [ 0.3117, -0.2594,  0.3073,  0.0662,  0.2612,  0.0479,  0.1705, -0.0499],
#          [ 0.2725,  0.0523, -0.1651,  0.0901, -0.1629, -0.0415, -0.1436,  0.2345],
#          [-0.2791, -0.1630, -0.0998, -0.2126,  0.0334, -0.3492,  0.3193, -0.3003],
#          [ 0.2730,  0.0588, -0.1148,  0.2185,  0.0551,  0.2857,  0.0387, -0.1115],
#          [ 0.0950, -0.0959,  0.1488,  0.3157,  0.2044, -0.1546,  0.2041,  0.0633],
#          [ 0.1795, -0.2155, -0.3500, -0.1366, -0.2712,  0.2901,  0.1018,  0.1464],
#          [ 0.1118, -0.0062,  0.2767, -0.2512,  0.0223, -0.2413,  0.1090, -0.1218],
#          [ 0.1083, -0.0737,  0.2932, -0.2096, -0.2109, -0.2109,  0.3180,  0.1178],
#          [ 0.3402, -0.2918, -0.3507, -0.2766, -0.2378,  0.1432,  0.1266,  0.2938],
#          [-0.1826, -0.2410,  0.1876, -0.1429,  0.2146, -0.0839,  0.2022, -0.2747],
#          [-0.1784,  0.1078,  0.0747, -0.0901,  0.2107,  0.2403, -0.2564, -0.1888],
#          [-0.2457, -0.0729,  0.2618,  0.1812, -0.2237, -0.2835, -0.2416, -0.3489],
#          [-0.2728, -0.0874,  0.2386,  0.0592, -0.2689, -0.2836,  0.1759, -0.2630],
#          [-0.0435,  0.1696, -0.1636, -0.0386, -0.0308, -0.0836, -0.1793, -0.3152],
#          [-0.2858, -0.1893,  0.3415, -0.1708, -0.2374,  0.0857,  0.0974,  0.1937],
#          [ 0.2687,  0.1969, -0.3505,  0.0314,  0.2142, -0.0327, -0.2083,  0.3371],
#          [-0.1322, -0.2013, -0.3187,  0.0158,  0.1567,  0.0783,  0.0699, -0.2681],
#          [-0.3302,  0.0062,  0.3224,  0.2040, -0.2059, -0.0459, -0.2606, -0.1706],
#          [ 0.0640,  0.1925,  0.2929, -0.3246,  0.2364, -0.2494,  0.1324,  0.2992],
#          [ 0.0050,  0.3217, -0.3012, -0.1350,  0.2062, -0.0770, -0.0724, -0.1474],
#          [ 0.2437,  0.1734,  0.1133, -0.1987, -0.2870,  0.0382,  0.1048, -0.1632]],
#         device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([-0.0989,  0.2388,  0.0282,  0.0160, -0.0870, -0.3202, -0.3324, -0.1690,
#          -0.1797,  0.1102, -0.1029, -0.1383,  0.3371,  0.1232,  0.2520, -0.1712,
#          -0.1444,  0.1299, -0.2356, -0.2311, -0.0171, -0.1293, -0.2650,  0.2097,
#           0.2843,  0.0574, -0.0616, -0.3275, -0.1288,  0.0900,  0.1667, -0.0447,
#          -0.1398,  0.1970, -0.2816,  0.2235, -0.1372,  0.0054, -0.0699,  0.0429,
#          -0.1068,  0.2571, -0.0092,  0.2760,  0.3399, -0.1722, -0.2579,  0.2837,
#           0.2770, -0.2700], device='cuda:0', dtype=torch.float64,
#         requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0109, -0.1395, -0.1158,  ...,  0.1315, -0.0367, -0.0598],
#          [-0.0342, -0.0683,  0.0240,  ...,  0.1098,  0.1142, -0.0488],
#          [-0.0316,  0.0682, -0.0386,  ..., -0.1245,  0.0987,  0.0164],
#          ...,
#          [-0.0450,  0.0018, -0.0635,  ..., -0.0187, -0.0550, -0.0502],
#          [-0.0746,  0.0232,  0.0397,  ...,  0.0789, -0.0560, -0.0947],
#          [-0.1088, -0.0835, -0.0582,  ...,  0.0957, -0.0141, -0.0045]],
#         device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([-0.0106,  0.1180,  0.0804,  0.0238, -0.0851, -0.0768,  0.1126,  0.1017,
#           0.0819, -0.1103,  0.1101, -0.0135,  0.1042,  0.1228,  0.0155, -0.0588,
#           0.1330, -0.0737,  0.0924, -0.1356, -0.0445, -0.1233, -0.0634,  0.0601,
#          -0.1013, -0.1223,  0.1011,  0.0755, -0.0015, -0.0997, -0.0375, -0.0458,
#           0.0873, -0.0463, -0.0407, -0.1002, -0.0666,  0.0766,  0.0911,  0.0205],
#         device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([[-0.0593,  0.1519,  0.0312, -0.0610, -0.0548, -0.0221,  0.0750,  0.0578,
#            0.1146, -0.0071,  0.1308, -0.0642, -0.0728, -0.0584, -0.1483, -0.1038,
#           -0.1431, -0.0093,  0.0015, -0.0410, -0.1081,  0.1435, -0.0524,  0.0753,
#            0.1101, -0.1039, -0.0198,  0.0914,  0.1533, -0.0199,  0.1146, -0.1241,
#           -0.1027,  0.1300, -0.0150,  0.1562,  0.0115, -0.0656,  0.1502,  0.1383]],
#         device='cuda:0', dtype=torch.float64, requires_grad=True),
#  Parameter containing:
#  tensor([0.0147], device='cuda:0', dtype=torch.float64, requires_grad=True)]

# %%
learning_rate = 0.01
n_epochs = 100

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
mse = nn.MSELoss()

# %%
def train(model, optimizer, criterion, train_loader, X_val, y_val, n_epochs):
    model.train()
    losses = []
    val_losses = []
    for epoch in range(n_epochs):
        total_loss = 0.
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            loss = criterion(y_pred, y_batch)
            total_loss += loss.item()
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        mean_loss = total_loss / len(train_loader)
        y_val_pred = model(X_val)
        val_loss = criterion(y_val_pred, y_val)
        losses.append(mean_loss)
        val_losses.append(val_loss.item())
        print(f"Epoch {epoch + 1}/{n_epochs}, Loss: {mean_loss:.4f}, Validation Loss: {val_loss.item()}")
    return losses, val_losses

# %%
train_loss, val_loss = train(model, optimizer, mse, train_loader, X_valid, y_valid, n_epochs)
# Out:
# Epoch 1/100, Loss: 0.9196, Validation Loss: 0.8511557577231098
# Epoch 2/100, Loss: 0.7260, Validation Loss: 0.6496073953737886
# Epoch 3/100, Loss: 0.5700, Validation Loss: 0.5259017928526946
# Epoch 4/100, Loss: 0.5025, Validation Loss: 0.4795451673391364
# Epoch 5/100, Loss: 0.4763, Validation Loss: 0.45537036849059337
# Epoch 6/100, Loss: 0.4558, Validation Loss: 0.43669546310663004
# Epoch 7/100, Loss: 0.4403, Validation Loss: 0.4196342226473432
# Epoch 8/100, Loss: 0.4226, Validation Loss: 0.4034619515308636
# Epoch 9/100, Loss: 0.4081, Validation Loss: 0.38979707842246986
# Epoch 10/100, Loss: 0.3960, Validation Loss: 0.377298637678777
# Epoch 11/100, Loss: 0.3845, Validation Loss: 0.36631385501049984
# Epoch 12/100, Loss: 0.3736, Validation Loss: 0.356834797417894
# Epoch 13/100, Loss: 0.3644, Validation Loss: 0.348144477113759
# Epoch 14/100, Loss: 0.3565, Validation Loss: 0.3410445855595502
# Epoch 15/100, Loss: 0.3486, Validation Loss: 0.3348637609861708
# Epoch 16/100, Loss: 0.3440, Validation Loss: 0.32911487791112454
# Epoch 17/100, Loss: 0.3381, Validation Loss: 0.3241090118894659
# Epoch 18/100, Loss: 0.3336, Validation Loss: 0.32032466834835
# Epoch 19/100, Loss: 0.3285, Validation Loss: 0.31684950262770883
# Epoch 20/100, Loss: 0.3260, Validation Loss: 0.3142714320142189
# Epoch 21/100, Loss: 0.3224, Validation Loss: 0.310476869890142
# Epoch 22/100, Loss: 0.3198, Validation Loss: 0.30841163666093574
# Epoch 23/100, Loss: 0.3159, Validation Loss: 0.305106669328136
# Epoch 65/100, Loss: 0.2757, Validation Loss: 0.27210949759654496
# Epoch 66/100, Loss: 0.2754, Validation Loss: 0.27166335970481137
# Epoch 67/100, Loss: 0.2752, Validation Loss: 0.27263572732081703
# Epoch 68/100, Loss: 0.2745, Validation Loss: 0.27089739698616255
# Epoch 69/100, Loss: 0.2746, Validation Loss: 0.2706935290866187
# Epoch 70/100, Loss: 0.2739, Validation Loss: 0.27023277791653216
# Epoch 71/100, Loss: 0.2742, Validation Loss: 0.2716111954381189
# Epoch 72/100, Loss: 0.2739, Validation Loss: 0.269912356165407
# Epoch 73/100, Loss: 0.2728, Validation Loss: 0.270710421427176
# Epoch 74/100, Loss: 0.2726, Validation Loss: 0.2691115964034213
# Epoch 75/100, Loss: 0.2722, Validation Loss: 0.26972272230865546
# Epoch 76/100, Loss: 0.2721, Validation Loss: 0.26883204193655647
# Epoch 77/100, Loss: 0.2711, Validation Loss: 0.26812719295187865
# Epoch 78/100, Loss: 0.2713, Validation Loss: 0.2679676832801936
# Epoch 79/100, Loss: 0.2718, Validation Loss: 0.26817485230368726
# Epoch 80/100, Loss: 0.2705, Validation Loss: 0.26816607357647654
# Epoch 81/100, Loss: 0.2705, Validation Loss: 0.266968991711153
# Epoch 82/100, Loss: 0.2704, Validation Loss: 0.2672820271890904
# Epoch 83/100, Loss: 0.2693, Validation Loss: 0.2668828001772211
# Epoch 84/100, Loss: 0.2694, Validation Loss: 0.266237490105753
# Epoch 85/100, Loss: 0.2686, Validation Loss: 0.2662231803970927
# Epoch 86/100, Loss: 0.2689, Validation Loss: 0.26578824137717266
# Epoch 87/100, Loss: 0.2679, Validation Loss: 0.26628207530107567
# Epoch 88/100, Loss: 0.2677, Validation Loss: 0.265229613192054
# Epoch 89/100, Loss: 0.2675, Validation Loss: 0.26527579550504354
# Epoch 90/100, Loss: 0.2673, Validation Loss: 0.2646859745686568
# Epoch 91/100, Loss: 0.2675, Validation Loss: 0.26469007235274244
# Epoch 92/100, Loss: 0.2680, Validation Loss: 0.2646661086566054
# Epoch 93/100, Loss: 0.2668, Validation Loss: 0.26415535692512404
# Epoch 94/100, Loss: 0.2659, Validation Loss: 0.2637766810951175
# Epoch 95/100, Loss: 0.2675, Validation Loss: 0.26339371762452773
# Epoch 96/100, Loss: 0.2661, Validation Loss: 0.2634448720497149
# Epoch 97/100, Loss: 0.2650, Validation Loss: 0.2630521654021691
# Epoch 98/100, Loss: 0.2650, Validation Loss: 0.2631139440880179
# Epoch 99/100, Loss: 0.2646, Validation Loss: 0.2635426292927124
# Epoch 100/100, Loss: 0.2653, Validation Loss: 0.2624457663801156

# %%
plt.plot(list(range(n_epochs)), train_loss)
plt.plot(list(range(n_epochs)), val_loss)
plt.grid()
plt.show()

# %%
with torch.no_grad():
    y_test_pred = model(X_test)
    loss_test = mse(y_test_pred, y_test)
loss_test
# Out:
# tensor(0.2750, device='cuda:0', dtype=torch.float64)
