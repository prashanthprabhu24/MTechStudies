# %% [markdown]
# ### Set Up

# %%
import torch
import torch.nn as nn
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from torch.utils.data import TensorDataset, DataLoader

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ### Load Dataset

# %%
def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
    with tarfile.open(tarball_path) as housing_tarball:
        housing_tarball.extractall(path="datasets", filter="data")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

# %%
housing_full = load_housing_data()

# %% [markdown]
# ### Data Processing

# %%
housing_full = housing_full.drop("ocean_proximity", axis=1)

# %%
imputer = SimpleImputer(strategy="median")
imputer.fit(housing_full)
# Out:
# SimpleImputer(strategy='median')

# %%
X = imputer.transform(housing_full)
housing_full = pd.DataFrame(X, columns=housing_full.columns, index=housing_full.index)

# %%
train_set, test_set = train_test_split(housing_full, test_size=0.2, random_state=42)
train_set, val_set = train_test_split(train_set, test_size=0.2, random_state=42)
housing_full.shape, train_set.shape, val_set.shape, test_set.shape
# Out:
# ((20640, 9), (13209, 9), (3303, 9), (4128, 9))

# %%
X_train, y_train = train_set.drop("median_house_value", axis=1), train_set["median_house_value"]
X_valid, y_valid = val_set.drop("median_house_value", axis=1), val_set["median_house_value"]
X_test, y_test = test_set.drop("median_house_value", axis=1), test_set["median_house_value"]

# %%
X_train = torch.tensor(X_train.to_numpy(), dtype=torch.float64, device=device)
X_valid = torch.tensor(X_valid.to_numpy(), dtype=torch.float64, device=device)
X_test = torch.tensor(X_test.to_numpy(), dtype=torch.float64, device=device)

# %%
y_train = torch.tensor(y_train.to_numpy(), dtype=torch.float64, device=device).reshape(-1, 1)
y_valid = torch.tensor(y_valid.to_numpy(), dtype=torch.float64, device=device).reshape(-1, 1)
y_test = torch.tensor(y_test.to_numpy(), dtype=torch.float64, device=device).reshape(-1, 1)

# %%
means = X_train.mean(dim=0, keepdims=True)
stds = X_train.std(dim=0, keepdims=True)
X_train = (X_train- means) / stds
X_valid = (X_valid- means) / stds
X_test = (X_test- means) / stds

# %%
ymeans = y_train.mean(dim=0, keepdims=True)
ystds = y_train.std(dim=0, keepdims=True)
y_train = (y_train- ymeans) / ystds
y_valid = (y_valid- ymeans) / ystds
y_test = (y_test- ymeans) / ystds

# %%
train_dataset = TensorDataset(X_train, y_train)
batch_size = 1024
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, persistent_workers=True, num_workers=4, prefetch_factor=8)

# %% [markdown]
# ### Model

# %%
torch.manual_seed(42)
n_features = X_train.shape[1] # there are 8 input features

# %%
model = nn.Sequential(nn.Linear(n_features, 50), nn.ReLU(), nn.Linear(50, 40), nn.ReLU(), nn.Linear(40, 1))
model.to(device=device, dtype=torch.float64)
model
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=40, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=40, out_features=1, bias=True)
# )

# %%
learning_rate = 0.01
n_epochs = 100
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
mse = nn.MSELoss()

# %%
def train(model, optimizer, criterion, train_loader, X_val, y_val, n_epochs):
    model.train()
    losses = []
    val_losses = []
    for epoch in range(n_epochs):
        total_loss = 0.
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            loss = criterion(y_pred, y_batch)
            total_loss += loss.item()
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        mean_loss = total_loss / len(train_loader)
        y_val_pred = model(X_val)
        val_loss = criterion(y_val_pred, y_val)
        losses.append(mean_loss)
        val_losses.append(val_loss.item())
        print(f"Epoch {epoch + 1}/{n_epochs}, Loss: {mean_loss:.4f}, Validation Loss: {val_loss.item()}")
    return losses, val_losses

# %%
train_loss, val_loss = train(model, optimizer, mse, train_loader, X_valid, y_valid, n_epochs)
# Out:
# Epoch 1/100, Loss: 0.9994, Validation Loss: 0.999786642996234
# Epoch 2/100, Loss: 0.9441, Validation Loss: 0.9488950674416173
# Epoch 3/100, Loss: 0.8948, Validation Loss: 0.9001583174706517
# Epoch 4/100, Loss: 0.8477, Validation Loss: 0.8503430167274355
# Epoch 5/100, Loss: 0.7988, Validation Loss: 0.7988517386864289
# Epoch 6/100, Loss: 0.7484, Validation Loss: 0.7465612241735583
# Epoch 7/100, Loss: 0.6991, Validation Loss: 0.6955335633189742
# Epoch 8/100, Loss: 0.6534, Validation Loss: 0.6482019513708647
# Epoch 9/100, Loss: 0.6127, Validation Loss: 0.6070146977627878
# Epoch 10/100, Loss: 0.5795, Validation Loss: 0.57322808865603
# Epoch 11/100, Loss: 0.5526, Validation Loss: 0.5464447454904549
# Epoch 12/100, Loss: 0.5327, Validation Loss: 0.5258805736395036
# Epoch 13/100, Loss: 0.5178, Validation Loss: 0.5100712242384698
# Epoch 14/100, Loss: 0.5062, Validation Loss: 0.49790151614395234
# Epoch 15/100, Loss: 0.4973, Validation Loss: 0.4881000113830331
# Epoch 16/100, Loss: 0.4900, Validation Loss: 0.47989507967198536
# Epoch 17/100, Loss: 0.4837, Validation Loss: 0.47288105659215907
# Epoch 18/100, Loss: 0.4783, Validation Loss: 0.4666645759650428
# Epoch 19/100, Loss: 0.4730, Validation Loss: 0.4608891658148177
# Epoch 20/100, Loss: 0.4677, Validation Loss: 0.455619742021999
# Epoch 21/100, Loss: 0.4629, Validation Loss: 0.45048808617143776
# Epoch 22/100, Loss: 0.4588, Validation Loss: 0.44565368051881793
# Epoch 23/100, Loss: 0.4538, Validation Loss: 0.44092494997260023
# Epoch 24/100, Loss: 0.4496, Validation Loss: 0.43645953845229124
# Epoch 25/100, Loss: 0.4451, Validation Loss: 0.43198666593534224
# Epoch 26/100, Loss: 0.4411, Validation Loss: 0.4277339519196179
# Epoch 27/100, Loss: 0.4369, Validation Loss: 0.4236652011001462
# Epoch 28/100, Loss: 0.4329, Validation Loss: 0.4195282004617566
# Epoch 29/100, Loss: 0.4291, Validation Loss: 0.41551338010498573
# Epoch 30/100, Loss: 0.4251, Validation Loss: 0.4116008032657934
# Epoch 31/100, Loss: 0.4213, Validation Loss: 0.40777570617427045
# Epoch 32/100, Loss: 0.4176, Validation Loss: 0.40401091499652486
# Epoch 33/100, Loss: 0.4138, Validation Loss: 0.4002522172099896
# Epoch 34/100, Loss: 0.4104, Validation Loss: 0.39665738898065955
# Epoch 77/100, Loss: 0.3261, Validation Loss: 0.31534611920051286
# Epoch 78/100, Loss: 0.3252, Validation Loss: 0.31463076274732893
# Epoch 79/100, Loss: 0.3246, Validation Loss: 0.3137832829626588
# Epoch 80/100, Loss: 0.3234, Validation Loss: 0.3131047236722724
# Epoch 81/100, Loss: 0.3228, Validation Loss: 0.31222506097475045
# Epoch 82/100, Loss: 0.3217, Validation Loss: 0.3115864584802403
# Epoch 83/100, Loss: 0.3209, Validation Loss: 0.3108925663503843
# Epoch 84/100, Loss: 0.3205, Validation Loss: 0.31009949969386547
# Epoch 85/100, Loss: 0.3199, Validation Loss: 0.3094611039735931
# Epoch 86/100, Loss: 0.3187, Validation Loss: 0.30892253376213236
# Epoch 87/100, Loss: 0.3185, Validation Loss: 0.30834167478151187
# Epoch 88/100, Loss: 0.3174, Validation Loss: 0.30761227641478167
# Epoch 89/100, Loss: 0.3168, Validation Loss: 0.30711302957969744
# Epoch 90/100, Loss: 0.3166, Validation Loss: 0.30646372858392157
# Epoch 91/100, Loss: 0.3158, Validation Loss: 0.30580675477848424
# Epoch 92/100, Loss: 0.3150, Validation Loss: 0.3052994276243711
# Epoch 93/100, Loss: 0.3145, Validation Loss: 0.30476489478690216
# Epoch 94/100, Loss: 0.3135, Validation Loss: 0.30419748731519414
# Epoch 95/100, Loss: 0.3131, Validation Loss: 0.3038199981939939
# Epoch 96/100, Loss: 0.3125, Validation Loss: 0.30314508712748073
# Epoch 97/100, Loss: 0.3118, Validation Loss: 0.3026698081689334
# Epoch 98/100, Loss: 0.3116, Validation Loss: 0.30222280816349995
# Epoch 99/100, Loss: 0.3109, Validation Loss: 0.3017619228665839
# Epoch 100/100, Loss: 0.3104, Validation Loss: 0.3011204210654591

# %%
plt.plot(list(range(n_epochs)), train_loss)
plt.plot(list(range(n_epochs)), val_loss)
plt.grid()
plt.show()

# %%
with torch.no_grad():
    y_test_pred = model(X_test)
    loss_test = mse(y_test_pred, y_test)
loss_test
# Out:
# tensor(0.3189, device='cuda:0', dtype=torch.float64)

# %% [markdown]
# ### Evals

# %%
def evaluate(model, data_loader, metric_fn, aggregate_fn=torch.mean):
    model.eval()
    metrics = []
    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            metric = metric_fn(y_pred, y_batch)
            metrics.append(metric)
    return aggregate_fn(torch.stack(metrics))

# %%
valid_dataset = TensorDataset(X_valid, y_valid)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size)
valid_mse = evaluate(model, valid_loader, mse)
valid_mse
# Out:
# tensor(0.2962, device='cuda:0', dtype=torch.float64)

# %%
valid_rmse = evaluate(model, valid_loader, mse, aggregate_fn=lambda metrics: torch.sqrt(torch.mean(metrics)))
valid_rmse
# Out:
# tensor(0.5443, device='cuda:0', dtype=torch.float64)

# %%
import torchmetrics

def evaluate_tm(model, data_loader, metric):
    model.eval()
    metric.reset() # reset the metric at the beginning
    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            metric.update(y_pred, y_batch) # update it at each iteration
    return metric.compute() # compute the final result at the end

# %%
rmse = torchmetrics.MeanSquaredError(squared=False).to(device)
rmse
# Out:
# MeanSquaredError()

# %%
evaluate_tm(model, valid_loader, rmse)
# Out:
# tensor(0.5487, device='cuda:0')
